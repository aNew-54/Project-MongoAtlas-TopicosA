# %% [markdown]
# DELETES

# %%
from connect import db

eliminar = db.libros

# Delete One
res = eliminar.delete_one(
    {'titulo': '1984'}
)
print('Se eliminó', res.deleted_count, 'libro')
# Out:
# Conexión exitosa a Atlas
# Conectado a MONGO DB Atlas: Base de Datos: biblioteca25
# Colecciones:  ['libros']
# Se eliminó 1 libro
